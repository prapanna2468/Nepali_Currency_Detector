# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Define paths to the dataset
train_dir = 'C:\\Users\\ASUS\\Downloads\\Compressed\\archive\\train'
validation_dir = 'C:\\Users\\ASUS\\Downloads\\Compressed\\archive\\validate'

# Set image size and batch size
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,           # Normalize pixel values
    rotation_range=20,        # Rotate images up to 20 degrees
    width_shift_range=0.2,    # Shift width by 20%
    height_shift_range=0.2,   # Shift height by 20%
    shear_range=0.2,          # Apply shear transformation
    zoom_range=0.2,           # Zoom in/out by 20%
    horizontal_flip=True,     # Flip horizontally (valid for currencies)
    fill_mode='nearest'       # Fill missing pixels
)

# Only rescaling for validation
validation_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# Print class indices to verify
print("Class indices:", train_generator.class_indices)

# Calculate steps per epoch
steps_per_epoch = train_generator.samples // BATCH_SIZE
validation_steps = validation_generator.samples // BATCH_SIZE

# Load pre-trained MobileNetV2 without top layers
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model
base_model.trainable = False

# Build the model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(512, activation='relu'),
    Dropout(0.5),  # Add dropout to prevent overfitting
    Dense(5, activation='softmax')  # 5 classes
])

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
)

# Train the model (Phase 1: Frozen base model)
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=20,
    validation_data=validation_generator,
    validation_steps=validation_steps
)

# Fine-tuning (Phase 2): Unfreeze some layers
base_model.trainable = True
for layer in base_model.layers[:-20]:  # Freeze all but the last 20 layers
    layer.trainable = False

# Recompile with a lower learning rate
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=1e-5),
    metrics=['accuracy']
)

# Continue training
history_fine = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=validation_steps
)

# Plot accuracy and loss
plt.figure(figsize=(12, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'] + history_fine.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'] + history_fine.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'] + history_fine.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'] + history_fine.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Evaluate with confusion matrix
val_preds = []
val_labels = []
for i in range(validation_steps):
    x, y = next(validation_generator)
    preds = model.predict(x)
    val_preds.extend(np.argmax(preds, axis=1))
    val_labels.extend(np.argmax(y, axis=1))

# Generate confusion matrix
cm = confusion_matrix(val_labels, val_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Save the model
model.save('currency_detector.h5')
# Out:
# Found 8498 images belonging to 5 classes.
# Found 1969 images belonging to 5 classes.
# Class indices: {'100': 0, '1000': 1, '500': 2, 'Fake 500': 3, 'fake 100': 4}
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1039s 4s/step - accuracy: 0.7747 - loss: 0.6503 - val_accuracy: 0.8268 - val_loss: 0.5213
# Epoch 2/20
#   1/265 ━━━━━━━━━━━━━━━━━━━━ 3:12 731ms/step - accuracy: 0.8438 - loss: 0.5235
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 68s 256ms/step - accuracy: 0.8438 - loss: 0.5235 - val_accuracy: 0.8463 - val_loss: 0.4567
# Epoch 3/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 611s 2s/step - accuracy: 0.9352 - loss: 0.2046 - val_accuracy: 0.8473 - val_loss: 0.4233
# Epoch 4/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 68s 254ms/step - accuracy: 0.9062 - loss: 0.1966 - val_accuracy: 0.8438 - val_loss: 0.4359
# Epoch 5/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 609s 2s/step - accuracy: 0.9535 - loss: 0.1478 - val_accuracy: 0.8806 - val_loss: 0.3375
# Epoch 6/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 68s 253ms/step - accuracy: 1.0000 - loss: 0.0341 - val_accuracy: 0.8837 - val_loss: 0.3301
# Epoch 7/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 606s 2s/step - accuracy: 0.9544 - loss: 0.1343 - val_accuracy: 0.8822 - val_loss: 0.3432
# Epoch 8/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 66s 249ms/step - accuracy: 0.9062 - loss: 0.1405 - val_accuracy: 0.8755 - val_loss: 0.3727
# Epoch 9/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 581s 2s/step - accuracy: 0.9651 - loss: 0.1025 - val_accuracy: 0.9232 - val_loss: 0.2214
# Epoch 10/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 71s 265ms/step - accuracy: 0.9688 - loss: 0.1425 - val_accuracy: 0.9206 - val_loss: 0.2208
# Epoch 11/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 610s 2s/step - accuracy: 0.9633 - loss: 0.1067 - val_accuracy: 0.8822 - val_loss: 0.3715
# Epoch 12/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 68s 255ms/step - accuracy: 0.9375 - loss: 0.1320 - val_accuracy: 0.8842 - val_loss: 0.3614
# Epoch 13/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 616s 2s/step - accuracy: 0.9656 - loss: 0.1097 - val_accuracy: 0.9016 - val_loss: 0.3037
# Epoch 14/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 70s 262ms/step - accuracy: 1.0000 - loss: 0.0233 - val_accuracy: 0.9011 - val_loss: 0.2896
# Epoch 15/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 577s 2s/step - accuracy: 0.9709 - loss: 0.0872 - val_accuracy: 0.8837 - val_loss: 0.3859
# Epoch 16/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 65s 245ms/step - accuracy: 0.9688 - loss: 0.0930 - val_accuracy: 0.8868 - val_loss: 0.3660
# Epoch 17/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 551s 2s/step - accuracy: 0.9721 - loss: 0.0803 - val_accuracy: 0.9329 - val_loss: 0.1944
# Epoch 18/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 62s 233ms/step - accuracy: 0.9688 - loss: 0.0869 - val_accuracy: 0.9349 - val_loss: 0.1903
# Epoch 19/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 552s 2s/step - accuracy: 0.9736 - loss: 0.0760 - val_accuracy: 0.9042 - val_loss: 0.3060
# Epoch 20/20
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 64s 239ms/step - accuracy: 0.9688 - loss: 0.0685 - val_accuracy: 0.8929 - val_loss: 0.3407
# Epoch 1/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 601s 2s/step - accuracy: 0.8813 - loss: 0.3384 - val_accuracy: 0.9273 - val_loss: 0.2429
# Epoch 2/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 63s 237ms/step - accuracy: 0.9688 - loss: 0.1348 - val_accuracy: 0.9262 - val_loss: 0.2465
# Epoch 3/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 639s 2s/step - accuracy: 0.9573 - loss: 0.1225 - val_accuracy: 0.9201 - val_loss: 0.2646
# Epoch 4/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 65s 243ms/step - accuracy: 0.9688 - loss: 0.0714 - val_accuracy: 0.9201 - val_loss: 0.2646
# Epoch 5/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 569s 2s/step - accuracy: 0.9664 - loss: 0.0916 - val_accuracy: 0.9237 - val_loss: 0.2431
# Epoch 6/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 62s 234ms/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.9242 - val_loss: 0.2421
# Epoch 7/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 595s 2s/step - accuracy: 0.9739 - loss: 0.0762 - val_accuracy: 0.9436 - val_loss: 0.1788
# Epoch 8/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 64s 239ms/step - accuracy: 0.9688 - loss: 0.0692 - val_accuracy: 0.9436 - val_loss: 0.1790
# Epoch 9/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 591s 2s/step - accuracy: 0.9802 - loss: 0.0610 - val_accuracy: 0.9380 - val_loss: 0.1842
# Epoch 10/10
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 78s 292ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9380 - val_loss: 0.1843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 731ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 731ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 692ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 702ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 842ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 702ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 777ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 804ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
